# %%
from casq import celldesigner2qual

# %%
input_map = "Apoptosis_VS_SSA_AN.xml"
output_model = "Apoptosis_VS_SSA_AN.sbml"
celldesigner2qual.map_to_model(input_map, output_model)

# %%
import maboss
# Out:
# <style>.mymodule-menu { color : green; background-color : None; }</style>

# %%
model = maboss.gsparser.loadSBML("Apoptosis_VS_SSA_AN.sbml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = maboss.gsparser.loadSBML("Apoptosis_VS_SSA_AN.sbml")
#
# File /opt/anaconda3/lib/python3.11/site-packages/maboss/gsparser.py:150, in loadSBML(sbml_filename, cfg_filename, use_sbml_names, cmaboss)
#     147 if cmaboss:
#     148     return SBMLSSimulation(sbml_filename, cfg_filename, use_sbml_names)
# --> 150 return sbml_to_maboss(sbml_filename, cfg_filename, use_sbml_names)
#
# File /opt/anaconda3/lib/python3.11/site-packages/maboss/simulation.py:456, in sbml_to_maboss(sbml_filename, cfg_filename, use_sbml_names)
#     454 default_cfg_filename = new_output_file("cfg")
#     455 sbml_to_bnd_and_cfg(sbml_filename, bnd_filename, default_cfg_filename, use_sbml_names)
# --> 456 sim = load(bnd_filename, cfg_filename if cfg_filename is not None else default_cfg_filename)
# ...
